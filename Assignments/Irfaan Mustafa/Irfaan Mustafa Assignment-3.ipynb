# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Loading Dataset

# %%
df =pd.read_csv('abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# Univariate Analysis

# %%
sns.kdeplot(df['Rings'], fill=True, color="#2C5F2D")
# Out:
# <AxesSubplot: xlabel='Rings', ylabel='Density'>

# %% [markdown]
# Bi-Variate Analysis

# %%
sns.scatterplot(df["Length"],color='#97BC62FF') 
sns.scatterplot(df["Height"],color='#2C5F2D')
# Out:
# <AxesSubplot: ylabel='Length'>

# %% [markdown]
# Multi-Variate

# %%
sns.pairplot(df, kind="kde", hue="Rings", palette="Accent")
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1191: UserWarning: No contour levels were found within the data range.
#   cset = contour_func(
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1191: UserWarning: No contour levels were found within the data range.
#   cset = contour_func(
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1191: UserWarning: No contour levels were found within the data range.
#   cset = contour_func(
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1191: UserWarning: No contour levels were found within the data range.
#   cset = contour_func(
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:1191: UserWarning: No contour levels were found within the data range.
# ...

# %% [markdown]
# Descriptive Stats

# %%
df.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight        Rings
# count      4177.000000     4177.000000   4177.000000  4177.000000
# ...

# %% [markdown]
# Missing Values

# %%
df.dropna()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
plt.scatter(x = df['Length'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Length'] <= 0.8) & (df['Length'] >= 0.2) & (df['Rings'] <= 20) & (df['Rings'] >= 5)]

# %%
plt.scatter(x = df['Length'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Diameter'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Height'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Height'] >= 0.03) & (df['Height'] <= 0.3)]

# %%
plt.scatter(x = df['Height'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Whole weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Whole weight'] <= 2.5)]

# %%
plt.scatter(x = df['Whole weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Shucked weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Shucked weight'] <= 1)]

# %%
plt.scatter(x = df['Shucked weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Viscera weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Viscera weight'] <= 0.5)]

# %%
plt.scatter(x = df['Viscera weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Shell weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
df = df[(df['Shell weight'] <= 0.5)]

# %%
plt.scatter(x = df['Shell weight'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %%
plt.scatter(x = df['Rings'], y = df['Rings'], c="#2C5F2D")
plt.grid(True)

# %% [markdown]
# Encoding

# %%
df.dtypes
# Out:
# Sex                 int32
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
label_encoder = preprocessing.LabelEncoder()
df['Sex']= label_encoder.fit_transform(df['Sex'])
df['Sex'].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
df.dtypes
# Out:
# Sex                 int64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# Splitting

# %%
x = df
y = df['Rings']+1.5

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
y
# Out:
# 0       16.5
# 1        8.5
# 2       10.5
# 3       11.5
# 4        8.5
#         ...
# 4172    12.5
# 4173    11.5
# 4174    10.5
# 4175    11.5
# 4176    13.5
# Name: Rings, Length: 3893, dtype: float64

# %% [markdown]
# Model Building

# %%
standardScale = StandardScaler()
x=standardScale.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)

# %%
regressor = RandomForestRegressor(n_estimators = 500, random_state = 0)

# %%
regressor.fit(x_train, y_train)
regressor.score(x_train,y_train)*100
# Out:
# 100.0

# %%
regressor.fit(x_test, y_test)
regressor.score(x_test,y_test)*100
# Out:
# 99.99997850583188
